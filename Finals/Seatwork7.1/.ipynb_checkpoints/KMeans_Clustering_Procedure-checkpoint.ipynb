# %% [markdown]
# # K-Means Clustering Procedure
#
# This notebook demonstrates **K-Means Clustering** on two datasets:
#
# 1. `CC GENERAL.csv` — Credit Card Customer Data
# 2. `bank_transactions_data_2.csv` — Bank Transactions Data  (Activity)
#
# Each dataset section includes:
# - Preprocessing and scaling
# - Elbow Method visualization
# - Clustering analysis
# - **Student activity:** Do the procedures on the bank transactions data

# %%
# ============================================================
# IMPORT LIBRARIES
# ============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## PART 1: Credit Card Data Clustering

# %%
# --- LOAD DATASET ---
df_cc = pd.read_csv('CC GENERAL.csv')
print("Credit Card Dataset Loaded Successfully.")
print(df_cc.shape)
df_cc.head()
# Out:
# Credit Card Dataset Loaded Successfully.
# (8950, 18)
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# ...

# %%
# --- DATA PREPROCESSING ---
df_cc = df_cc.dropna()

# Drop customer ID if present
if 'CUST_ID' in df_cc.columns:
    df_cc = df_cc.drop(columns=['CUST_ID'])

scaler = StandardScaler()
scaled_cc = scaler.fit_transform(df_cc)

# %%
# --- K-MEANS ELBOW METHOD ---
inertia = []
k_values = range(2, 50)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_cc)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker='o')
plt.title('Elbow Method for Credit Card Data')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

# %%
# --- FIT OPTIMAL MODEL ---
k_optimal = 10
kmeans_cc = KMeans(n_clusters=k_optimal, random_state=42)
df_cc['Cluster'] = kmeans_cc.fit_predict(scaled_cc)

df_cc.groupby('Cluster').mean()
# Out:
#              BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0        5252.139405           0.955469   1019.283316        616.093904
# 1         764.213394           0.961222    929.550680        185.400274
# 2         907.791717           0.828373    387.123853        223.802209
# 3        4503.333537           0.983471   9945.073068       4516.177955
# 4        1357.464753           0.973882    232.949401        180.026089
# 5         132.860896           0.422145    365.978125        213.601442
# 6        2815.032534           0.987280   4451.403908       2964.714037
# 7        5109.411343           0.949545  29095.715500      24021.496000
# 8        4536.490620           0.976793    354.772702        224.550618
# 9        1028.851150           0.968054   1667.364490       1395.410333
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                    403.189412   9603.547743             0.400688
# ...

# %%
# --- VISUALIZE CLUSTERS ---
plt.figure(figsize=(8, 5))
sns.countplot(x='Cluster', data=df_cc, palette='Set2')
plt.title('Cluster Distribution (Credit Card Data)')
plt.show()

# %% [markdown]
# ### Random Search Optimization on K-Means (Credit Card Data)

# %%
results = []

for i in range(25):
    k = np.random.randint(2, 100)
    init_method = np.random.choice(['k-means++', 'random'])
    max_iter = np.random.randint(100, 500)

    model = KMeans(n_clusters=k, init=init_method, max_iter=max_iter, random_state=42)
    labels = model.fit_predict(scaled_cc)
    silhouette = silhouette_score(scaled_cc, labels)

    results.append({
        'k': k,
        'init': init_method,
        'max_iter': max_iter,
        'silhouette_score': silhouette
    })

pd.DataFrame(results).sort_values(by='silhouette_score', ascending=False)
# Out:
#      k       init  max_iter  silhouette_score
# 10  10     random       247          0.229813
# 23  13  k-means++       182          0.220362
# 20  13  k-means++       320          0.220362
# 9   12     random       215          0.217208
# 2   19  k-means++       196          0.207773
# 8   26  k-means++       487          0.183291
# 17  26     random       129          0.180492
# 21  27  k-means++       180          0.180479
# 5   54  k-means++       271          0.175051
# 13  43  k-means++       161          0.173902
# 7   34  k-means++       115          0.170070
# 22  70  k-means++       162          0.164491
# 11  63     random       320          0.160946
# 3   68  k-means++       350          0.159725
# 0   96  k-means++       218          0.158938
# 6   61  k-means++       250          0.158067
# 4   61  k-means++       332          0.158067
# 14  93  k-means++       316          0.156637
# 12  90  k-means++       112          0.155177
# ...

# %% [markdown]
# ## 💳 PART 2: Bank Transactions Data Clustering

# %%
# --- LOAD DATASET ---
bank_trans = pd.read_csv('bank_transactions_data_2.csv ')
print("Bank Transaction data loaded.")
print(bank_trans.shape)
bank_trans.head()
# Out:
# Bank Transaction data loaded.
# (2512, 16)
#   TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0      TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1      TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2      TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3      TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4      TX000005   AC00411              13.45  2023-10-16 17:51:24
#
#   TransactionType   Location DeviceID      IP Address MerchantID Channel  \
# 0           Debit  San Diego  D000380  162.198.218.92       M015     ATM
# 1           Debit    Houston  D000051     13.149.61.4       M052     ATM
# 2           Debit       Mesa  D000235  215.97.143.157       M009  Online
# 3           Debit    Raleigh  D000187  200.13.225.150       M002  Online
# 4          Credit    Atlanta  D000308    65.164.3.100       M091  Online
#
#    CustomerAge CustomerOccupation  TransactionDuration  LoginAttempts  \
# ...

# %%
# --- DATA PREPROCESSING ---
# Drop non-numeric columns (e.g., text IDs)
bank_trans = bank_trans.dropna()

# %%
# Display current columns
print("Current columns:")
for i, col in enumerate(bank_trans.columns, 1):
    print(f"{i}. {col}")

# Ask user for input (comma-separated column names or numbers)
user_input = input("\nEnter column names or numbers to remove (comma-separated): ")

# Split and clean user input
choices = [x.strip() for x in user_input.split(',')]

# Handle both numbers and names
cols_to_drop = []
for choice in choices:
    if choice.isdigit():  # user entered a number
        idx = int(choice) - 1
        if 0 <= idx < len(bank_trans.columns):
            cols_to_drop.append(bank_trans.columns[idx])
    elif choice in bank_trans.columns:
        cols_to_drop.append(choice)

# Drop the selected columns
bank_trans_copy = bank_trans.drop(columns=cols_to_drop, errors='ignore')

print(f"\nDropped columns: {cols_to_drop}")
print(f"Remaining columns: {list(bank_trans_copy.columns)}")
# Out:
# Current columns:
# 1. TransactionID
# 2. AccountID
# 3. TransactionAmount
# 4. TransactionDate
# 5. TransactionType
# 6. Location
# 7. DeviceID
# 8. IP Address
# 9. MerchantID
# 10. Channel
# 11. CustomerAge
# 12. CustomerOccupation
# 13. TransactionDuration
# 14. LoginAttempts
# 15. AccountBalance
# 16. PreviousTransactionDate
# Enter column names or numbers to remove (comma-separated):  1,2,4,5,6,7,8,9,10,12,16
# Dropped columns: ['TransactionID', 'AccountID', 'TransactionDate', 'TransactionType', 'Location', 'DeviceID', 'IP Address', 'MerchantID', 'Channel', 'CustomerOccupation', 'PreviousTransactionDate']
# Remaining columns: ['TransactionAmount', 'CustomerAge', 'TransactionDuration', 'LoginAttempts', 'AccountBalance']

# %%
bank_trans_copy.head()
# Out:
#    TransactionAmount  CustomerAge  TransactionDuration  LoginAttempts  \
# 0              14.09           70                   81              1
# 1             376.24           68                  141              1
# 2             126.29           19                   56              1
# 3             184.50           26                   25              1
# 4              13.45           26                  198              1
#
#    AccountBalance
# 0         5112.21
# 1        13758.91
# 2         1122.35
# 3         8569.06
# 4         7429.40

# %%
scaler = StandardScaler()
scaled_bank = scaler.fit_transform(bank_trans_copy)

# %%
# --- ELBOW METHOD ---
inertia = []
k_values = range(2, 100)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_bank)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker='o')
plt.title('Elbow Method for Credit Card Data')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

# %%
# --- FIT OPTIMAL MODEL ---
k_optimal = 10
kmeans_bank = KMeans(n_clusters=k_optimal, random_state=42)
bank_trans_copy['Cluster'] = kmeans_bank.fit_predict(scaled_bank)

bank_trans_copy.groupby('Cluster').mean()
# Out:
#          TransactionAmount  CustomerAge  TransactionDuration  LoginAttempts  \
# Cluster
# 0               276.829170    53.929461            99.834025       1.012448
# 1               248.398426    24.616393           187.888525       1.009836
# 2               210.301980    44.118812           221.905941       1.019802
# 3               265.876667    54.137255           152.411765       3.862745
# 4               196.292385    62.082569            63.729358       1.009174
# 5               244.864529    26.400524            67.848168       1.010471
# 6               215.093141    34.317690            81.404332       1.007220
# 7               980.468834    45.798206           113.937220       1.017937
# 8               225.069316    61.826211           171.404558       1.008547
# 9               288.434091    33.409091           108.090909       4.181818
#
#          AccountBalance
# Cluster
# 0          12074.684398
# 1           1291.537836
# 2           8693.148020
# ...

# %%
# --- VISUALIZE CLUSTERS ---
plt.figure(figsize=(8, 5))
sns.countplot(x='Cluster', data=bank_trans_copy, palette='Set3')
plt.title('Cluster Distribution (Bank Transaction Data)')
plt.show()

# %% [markdown]
# ### Student Activity 2: Random Search Optimization on K-Means (Bank Transactions Data)
#
# **Task:**
# Perform a random search optimization to find the best K-Means configuration.
#
# **Instructions:**
# 1. Define random ranges for:
#    - `n_clusters` (e.g. 2–10)
#    - `init` method (`'k-means++'`, `'random'`)
#    - `max_iter` (e.g. 100–500)
# 2. Randomly sample 10–15 configurations and record:
#    - Inertia
#    - Silhouette Score
# 3. Identify the best configuration.

# %%
results = []

for i in range(15): #number of samples
    try:
        k = np.random.randint(2, 11) #n_clusters
        init_method = np.random.choice(['k-means++', 'random'])
        max_iter = np.random.randint(100, 500)

        model = KMeans(n_clusters=k, init=init_method, max_iter=max_iter, random_state=42)
        labels = model.fit_predict(scaled_bank)

        inertia = model.inertia_
        silhouette = silhouette_score(scaled_bank, labels)

        results.append({
            'k': k,
            'init': init_method,
            'max_iter': max_iter,
            'inertia': inertia,
            'silhouette_score': silhouette
        })
    except Exception as e:
        print(f"Skipped configuration due to error: {e}")

df_results = pd.DataFrame(results).sort_values(by='silhouette_score', ascending=False)
print("5 Best configurations:")
print(df_results.head(5))
# Out:
# 5 Best configurations:
#     k       init  max_iter      inertia  silhouette_score
# 5   6  k-means++       138  4928.551595          0.262485
# 7   6     random       205  4928.372207          0.262126
# 8   5     random       283  5711.730760          0.250382
# 12  5     random       442  5711.730760          0.250382
# 10  5     random       172  5711.730760          0.250382

# %%
#best configuration
print(df_results.head(1))
# Out:
#    k       init  max_iter      inertia  silhouette_score
# 5  6  k-means++       138  4928.551595          0.262485

# %%
#store best config
best_config = df_results.iloc[0]  # top row = best result

# %%
#test result
best_model = KMeans(
    n_clusters=int(best_config['k']),
    init=best_config['init'],
    max_iter=int(best_config['max_iter']),
    random_state=42
)

best_labels = best_model.fit_predict(scaled_bank)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

#scale data
scaler = StandardScaler()
scaled_bank = scaler.fit_transform(bank_trans.select_dtypes(include=[np.number]))  # numeric columns only

#use best config
best_model = KMeans(
    n_clusters=int(best_config['k']),
    init=best_config['init'],
    max_iter=int(best_config['max_iter']),
    random_state=42
)
best_labels = best_model.fit_predict(scaled_bank)

#reduce dimensions to 2 for visualization (uses PCA)
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(scaled_bank)

plt.figure(figsize=(8, 6))
plt.scatter(
    reduced_data[:, 0],
    reduced_data[:, 1],
    c=best_labels,
    cmap='viridis',
    s=40,
    alpha=0.7
)

#Plot centroids in PCA space
centroids_2d = pca.transform(best_model.cluster_centers_)
plt.scatter(
    centroids_2d[:, 0],
    centroids_2d[:, 1],
    c='red',
    marker='X',
    s=200,
    label='Centroids'
)

plt.title(f"K-Means Clusters (k={best_config['k']})", fontsize=14)
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend()
plt.colorbar(label="Cluster Label")
plt.show()

#PCA Loadings 
loadings = pd.DataFrame(
    pca.components_.T,
    columns=['PCA1', 'PCA2'],
    index=bank_trans.select_dtypes(include=[np.number]).columns
)

print("PCA Loadings — feature contributions per principal component:")
display(loadings)
# Out:
# PCA Loadings — feature contributions per principal component:
#                          PCA1      PCA2
# TransactionAmount   -0.111239 -0.058031
# CustomerAge          0.701836 -0.048449
# TransactionDuration -0.023221  0.707838
# LoginAttempts        0.049464  0.702194
# AccountBalance       0.701475  0.013188

# %% [markdown]
# # Conclusion/Analysis

# %% [markdown]
# *In this activity, I was able to learn about how clustering works and how it is done using sklearn K-means. I was also able to get the best possible K-means configuration for the task given and visualize its results by using dimensionality reduction via PCA. The visualization allowed me to understand how K-means uses centroids to cluster data which is otherwise undistinguishable with just usual methods of analysis and visualizations.*
